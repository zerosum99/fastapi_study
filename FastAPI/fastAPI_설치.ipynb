# %% [markdown]
# ## 1. fastapi 설치
#
# - pip install fastapi

# %% [markdown]
# ## 2. 유니콘 설치하기
#
# - conda install unicorn
#
# ### 2-1 오류 발생할 수 있음
# - 수동으로 설치할 것
#
# ###  수동 다운로드 및 설치
# - 패키지를 수동으로 다운로드하고 설치하는 방법도 있습니다.
#
# #### 패키지 수동 다운로드
# - unicorn 패키지를 수동으로 다운로드합니다.
# ##### 다운로드
# - wget https://conda.anaconda.org/conda-forge/osx-arm64/unicorn-2.0.1.post1-hb547adb_6.conda -O unicorn-2.0.1.post1-hb547adb_6.conda
#
# ##### 직접 설치
# - conda install ./unicorn-2.0.1.post1-hb547adb_6.conda

# %% [markdown]
# ## 재설치 할 requirements.txt 파일 만들기

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load requirements.txt
anyio==3.7.1
appnope==0.1.3
argon2-cffi==21.3.0
argon2-cffi-bindings==21.2.0
arrow==1.2.3
asttokens==2.2.1
attrs==23.1.0
backcall==0.2.0
beautifulsoup4==4.12.2
bleach==6.0.0
certifi==2023.7.22
cffi==1.15.1
charset-normalizer==3.1.0
comm==0.1.3
contourpy @ file:///Users/runner/miniforge3/conda-bld/contourpy_1673633752571/work
cycler @ file:///home/conda/feedstock_root/build_artifacts/cycler_1635519461629/work
debugpy==1.6.7
decorator==5.1.1
defusedxml==0.7.1
docopt==0.6.2
executing==1.2.0
fastapi==0.104.1
fastjsonschema==2.17.1
findspark==2.0.1
fonttools @ file:///Users/runner/miniforge3/conda-bld/fonttools_1683740812433/work
fqdn==1.5.1
hdfs==2.7.0
idna==3.4
ipykernel==6.23.1
ipython==8.13.2
ipython-genutils==0.2.0
isoduration==20.11.0
jedi==0.18.2
Jinja2==3.1.2
jsonpointer==2.3
jsonschema==4.17.3
jupyter-events==0.6.3
jupyter_client==8.2.0
jupyter_core==5.3.0
jupyter_server==2.6.0
jupyter_server_terminals==0.4.4
jupyterlab-pygments==0.2.2
kiwisolver @ file:///Users/runner/miniforge3/conda-bld/kiwisolver_1666805828768/work
koalas==0.22.0
MarkupSafe==2.1.2
matplotlib @ file:///Users/runner/miniforge3/conda-bld/matplotlib-suite_1678135673869/work
matplotlib-inline==0.1.6
midi-clip==0.7
mido==1.2.10
mistune==2.0.5
multipledispatch==1.0.0
munkres==1.1.4
mypy==1.3.0
mypy-extensions==1.0.0
nbclassic==1.0.0
nbclient==0.8.0
nbconvert==7.4.0
nbformat==5.9.0
nest-asyncio==1.5.6
nodeenv==1.8.0
notebook==6.5.4
notebook_shim==0.2.3
numpy @ file:///Users/runner/miniforge3/conda-bld/numpy_1682210472725/work
overrides==7.3.1
packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1681337016113/work
pandas @ file:///Users/runner/miniforge3/conda-bld/pandas_1685343120939/work
pandocfilters==1.5.0
parso==0.8.3
pexpect==4.8.0
pickleshare==0.7.5
Pillow @ file:///Users/runner/miniforge3/conda-bld/pillow_1684654235906/work
platformdirs==3.5.1
prometheus-client==0.17.0
prompt-toolkit==3.0.38
psutil==5.9.5
ptyprocess==0.7.0
pure-eval==0.2.2
py4j==0.10.9.7
pyarrow==12.0.0
pycparser==2.21
pydantic==1.10.9
Pygments==2.15.1
pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1652235407899/work
pyright==1.1.311
pyrsistent==0.19.3
pyspark==3.4.0
python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
python-json-logger==2.0.7
pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1680088766131/work
PyYAML==6.0
pyzmq==25.1.0
requests==2.31.0
rfc3339-validator==0.1.4
rfc3986-validator==0.1.1
seaborn==0.12.2
Send2Trash==1.8.2
six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
sniffio==1.3.0
soupsieve==2.4.1
stack-data==0.6.2
starlette==0.27.0
terminado==0.17.1
tinycss2==1.2.1
tornado @ file:///Users/runner/miniforge3/conda-bld/tornado_1684150351944/work
traitlets==5.9.0
typing_extensions==4.8.0
tzdata @ file:///home/conda/feedstock_root/build_artifacts/python-tzdata_1680081134351/work
uri-template==1.2.0
urllib3==2.0.2
wcwidth==0.2.6
webcolors==1.13
webencodings==0.5.1
websocket-client==1.5.2

# %%
# %%writefile requirements.txt
# anyio==3.7.1
# appnope==0.1.3
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# asttokens==2.2.1
# attrs==23.1.0
# backcall==0.2.0
# beautifulsoup4==4.12.2
# bleach==6.0.0
# certifi==2023.7.22
# cffi==1.15.1
# charset-normalizer==3.1.0
# comm==0.1.3
# contourpy @ file:///Users/runner/miniforge3/conda-bld/contourpy_1673633752571/work
# cycler @ file:///home/conda/feedstock_root/build_artifacts/cycler_1635519461629/work
# debugpy==1.6.7
# decorator==5.1.1
# defusedxml==0.7.1
# docopt==0.6.2
# executing==1.2.0
# fastapi==0.104.1
# fastjsonschema==2.17.1
# findspark==2.0.1
# fonttools @ file:///Users/runner/miniforge3/conda-bld/fonttools_1683740812433/work
# fqdn==1.5.1
# hdfs==2.7.0
# idna==3.4
# ipykernel==6.23.1
# ipython==8.13.2
# ipython-genutils==0.2.0
# isoduration==20.11.0
# jedi==0.18.2
# Jinja2==3.1.2
# jsonpointer==2.3
# jsonschema==4.17.3
# jupyter-events==0.6.3
# jupyter_client==8.2.0
# jupyter_core==5.3.0
# jupyter_server==2.6.0
# jupyter_server_terminals==0.4.4
# jupyterlab-pygments==0.2.2
# kiwisolver @ file:///Users/runner/miniforge3/conda-bld/kiwisolver_1666805828768/work
# koalas==0.22.0
# MarkupSafe==2.1.2
# matplotlib @ file:///Users/runner/miniforge3/conda-bld/matplotlib-suite_1678135673869/work
# matplotlib-inline==0.1.6
# midi-clip==0.7
# mido==1.2.10
# mistune==2.0.5
# multipledispatch==1.0.0
# munkres==1.1.4
# mypy==1.3.0
# mypy-extensions==1.0.0
# nbclassic==1.0.0
# nbclient==0.8.0
# nbconvert==7.4.0
# nbformat==5.9.0
# nest-asyncio==1.5.6
# nodeenv==1.8.0
# notebook==6.5.4
# notebook_shim==0.2.3
# numpy @ file:///Users/runner/miniforge3/conda-bld/numpy_1682210472725/work
# overrides==7.3.1
# packaging @ file:///home/conda/feedstock_root/build_artifacts/packaging_1681337016113/work
# pandas @ file:///Users/runner/miniforge3/conda-bld/pandas_1685343120939/work
# pandocfilters==1.5.0
# parso==0.8.3
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow @ file:///Users/runner/miniforge3/conda-bld/pillow_1684654235906/work
# platformdirs==3.5.1
# prometheus-client==0.17.0
# prompt-toolkit==3.0.38
# psutil==5.9.5
# ptyprocess==0.7.0
# pure-eval==0.2.2
# py4j==0.10.9.7
# pyarrow==12.0.0
# pycparser==2.21
# pydantic==1.10.9
# Pygments==2.15.1
# pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1652235407899/work
# pyright==1.1.311
# pyrsistent==0.19.3
# pyspark==3.4.0
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
# python-json-logger==2.0.7
# pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1680088766131/work
# PyYAML==6.0
# pyzmq==25.1.0
# requests==2.31.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# seaborn==0.12.2
# Send2Trash==1.8.2
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# sniffio==1.3.0
# soupsieve==2.4.1
# stack-data==0.6.2
# starlette==0.27.0
# terminado==0.17.1
# tinycss2==1.2.1
# tornado @ file:///Users/runner/miniforge3/conda-bld/tornado_1684150351944/work
# traitlets==5.9.0
# typing_extensions==4.8.0
# tzdata @ file:///home/conda/feedstock_root/build_artifacts/python-tzdata_1680081134351/work
# uri-template==1.2.0
# urllib3==2.0.2
# wcwidth==0.2.6
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.5.2
# Out:
# Writing requirements.txt
